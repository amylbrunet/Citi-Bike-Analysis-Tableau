# %%
# Dependencies and Setup
import pandas as pd

# %%
# skip the headers in every file after the first

CHUNK_SIZE = 50000
csv_file_list = ["input_data/jan_19_data.csv", "input_data/feb_19_data.csv", "input_data/mar_19_data.csv"]
output_file = "./combined_data.csv"

first_one = True
for csv_file_name in csv_file_list:

    if not first_one: # if it is not the first csv file then skip the header row (row 0) of that file
        skip_row = [0]
    else:
        skip_row = []

    chunk_container = pd.read_csv(csv_file_name, chunksize=CHUNK_SIZE, skiprows = skip_row)
    for chunk in chunk_container:
        chunk.to_csv(output_file, mode="a", index=False)
    first_one = False

# %%
# skip the headers in every file after the first

CHUNK_SIZE = 50000
csv_file_list = ["input_data/jan_19_data.csv", "input_data/feb_19_data.csv", "input_data/mar_19_data.csv", 
                 "input_data/apr_19_data.csv", "input_data/may_19_data.csv", "input_data/jun_19_data.csv",
                "input_data/jul_19_data.csv", "input_data/aug_19_data.csv", "input_data/sep_19_data.csv",
                "input_data/oct_19_data.csv", "input_data/nov_19_data.csv", "input_data/dec_19_data.csv"]
output_file = "./all_2019_data.csv"

first_one = True
for csv_file_name in csv_file_list:

    if not first_one: # if it is not the first csv file then skip the header row (row 0) of that file
        skip_row = [0]
    else:
        skip_row = []

    chunk_container = pd.read_csv(csv_file_name, chunksize=CHUNK_SIZE, skiprows = skip_row)
    for chunk in chunk_container:
        chunk.to_csv(output_file, mode="a", index=False)
    first_one = False

# %%
all_2019_data_path = "all_2019_data.csv"
all_2019_data = pd.read_csv(all_2019_data_path)

# %%
all_2019_df = all_2019_data
all_2019_df.head()
# Out:
#   tripduration                 starttime                  stoptime  \
# 0          320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1          316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2          591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3         2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4          303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#   start station id           start station name start station latitude  \
# 0             3160  Central Park West & W 76 St            40.77896784
# 1              519        Pershing Square North              40.751873
# 2             3171      Amsterdam Ave & W 82 St            40.78524672
# 3              504              1 Ave & E 16 St            40.73221853
# 4              229               Great Jones St            40.72743423
#
#   start station longitude end station id        end station name  \
# 0            -73.97374737           3283  W 89 St & Columbus Ave
# ...

# %%
all_2019_df.dropna()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 20552096           93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 20552097          786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 20552098          351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 20552099         1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 20552100          310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#          start station id                start station name  \
# ...

# %%
all_2019_df = all_2019_df[all_2019_df.gender != 0]

# %%
output_file = "clean_2019_data.csv"
all_2019_df.to_csv(output_file, mode="a", index=False)
